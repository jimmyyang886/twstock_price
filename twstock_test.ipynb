# %%
import twstock
twstock.__update_codes()

# %%
import twstock
stock = twstock.realtime.get('2330')
print(stock)

twstock.realtime.get(['2330', '2337', '2409'])
# Out:
# {'timestamp': 1589524200.0, 'info': {'code': '2330', 'channel': '2330.tw', 'name': '台積電', 'fullname': '台灣積體電路製造股份有限公司', 'time': '2020-05-15 14:30:00'}, 'realtime': {'latest_trade_price': '298.0000', 'trade_volume': '6262', 'accumulate_trade_volume': '42219', 'best_bid_price': ['297.5000', '297.0000', '296.5000', '296.0000', '295.5000'], 'best_bid_volume': ['128', '298', '318', '336', '364'], 'best_ask_price': ['298.0000', '298.5000', '299.0000', '299.5000', '300.0000'], 'best_ask_volume': ['1044', '1878', '1749', '1003', '2059'], 'open': '297.5000', 'high': '298.5000', 'low': '294.5000'}, 'success': True}
# {'2330': {'timestamp': 1589524200.0,
#   'info': {'code': '2330',
#    'channel': '2330.tw',
#    'name': '台積電',
#    'fullname': '台灣積體電路製造股份有限公司',
#    'time': '2020-05-15 14:30:00'},
#   'realtime': {'latest_trade_price': '298.0000',
#    'trade_volume': '6262',
#    'accumulate_trade_volume': '42219',
#    'best_bid_price': ['297.5000',
#     '297.0000',
#     '296.5000',
#     '296.0000',
#     '295.5000'],
#    'best_bid_volume': ['128', '298', '318', '336', '364'],
#    'best_ask_price': ['298.0000',
#     '298.5000',
#     '299.0000',
#     '299.5000',
#     '300.0000'],
#    'best_ask_volume': ['1044', '1878', '1749', '1003', '2059'],
#    'open': '297.5000',
#    'high': '298.5000',
#    'low': '294.5000'},
#   'success': True},
#  '2337': {'timestamp': 1589524200.0,
#   'info': {'code': '2337',
#    'channel': '2337.tw',
#    'name': '旺宏',
#    'fullname': '旺宏電子股份有限公司',
#    'time': '2020-05-15 14:30:00'},
#   'realtime': {'latest_trade_price': '32.5000',
#    'trade_volume': '2398',
#    'accumulate_trade_volume': '49439',
#    'best_bid_price': ['32.5000', '32.4500', '32.4000', '32.3500', '32.3000'],
#    'best_bid_volume': ['1011', '393', '392', '357', '856'],
#    'best_ask_price': ['32.5500', '32.6000', '32.6500', '32.7000', '32.7500'],
#    'best_ask_volume': ['89', '139', '819', '128', '56'],
#    'open': '33.4000',
#    'high': '33.4500',
#    'low': '32.2000'},
#   'success': True},
#  '2409': {'timestamp': 1589524200.0,
#   'info': {'code': '2409',
#    'channel': '2409.tw',
#    'name': '友達',
#    'fullname': '友達光電股份有限公司',
#    'time': '2020-05-15 14:30:00'},
#   'realtime': {'latest_trade_price': '7.6100',
#    'trade_volume': '4273',
#    'accumulate_trade_volume': '62509',
#    'best_bid_price': ['7.6100', '7.6000', '7.5900', '7.5800', '7.5700'],
#    'best_bid_volume': ['2682', '3100', '941', '2404', '670'],
#    'best_ask_price': ['7.6300', '7.6400', '7.6500', '7.6600', '7.6700'],
#    'best_ask_volume': ['20', '2', '105', '120', '418'],
#    'open': '7.7800',
#    'high': '7.8100',
#    'low': '7.5800'},
#   'success': True},
#  'success': True}

# %%
import requests
import pandas as pd

url="https://www.twse.com.tw/exchangeReport/STOCK_DAY?response=json&date=20200516&stockNo=2330&_=1589583929315"

headers={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36'}

res=requests.get(url, headers)

if res.status_code == requests.codes.ok:
    print("OK")

res.json()
# Out:
# OK
# {'stat': 'OK',
#  'date': '20200516',
#  'title': '109年05月 2330 台積電           各日成交資訊',
#  'fields': ['日期', '成交股數', '成交金額', '開盤價', '最高價', '最低價', '收盤價', '漲跌價差', '成交筆數'],
#  'data': [['109/05/04',
#    '72,252,861',
#    '21,341,931,218',
#    '294.50',
#    '296.50',
#    '294.00',
#    '295.00',
#    '-9.50',
#    '37,736'],
#   ['109/05/05',
#    '23,988,405',
#    '7,104,774,785',
#    '296.50',
#    '298.00',
#    '295.00',
#    '295.50',
#    '+0.50',
#    '13,569'],
#   ['109/05/06',
#    '35,704,479',
#    '10,524,838,077',
#    '294.50',
#    '296.00',
#    '292.50',
#    '296.00',
#    '+0.50',
#    '16,046'],
#   ['109/05/07',
#    '28,017,198',
#    '8,321,170,642',
#    '294.50',
#    '299.00',
#    '294.50',
#    '297.50',
#    '+1.50',
#    '13,149'],
#   ['109/05/08',
#    '35,613,893',
#    '10,619,091,212',
#    '300.00',
#    '300.00',
#    '296.00',
#    '297.50',
#    ' 0.00',
#    '14,345'],
#   ['109/05/11',
#    '32,379,019',
#    '9,729,431,840',
#    '300.00',
#    '301.50',
#    '298.50',
#    '301.00',
#    '+3.50',
#    '14,920'],
#   ['109/05/12',
#    '52,494,788',
#    '15,553,012,596',
#    '297.50',
#    '298.50',
#    '295.00',
#    '295.00',
#    '-6.00',
#    '29,073'],
#   ['109/05/13',
#    '46,158,418',
#    '13,619,538,824',
#    '293.00',
#    '297.00',
#    '292.50',
#    '297.00',
#    '+2.00',
#    '14,555'],
#   ['109/05/14',
#    '34,480,948',
#    '10,119,787,160',
#    '293.00',
#    '295.00',
#    '292.50',
#    '293.00',
#    '-4.00',
#    '21,482'],
#   ['109/05/15',
#    '44,304,804',
#    '13,170,466,660',
#    '297.50',
#    '298.50',
#    '294.50',
#    '298.00',
#    '+5.00',
#    '20,071']],
#  'notes': ['符號說明:+/-/X表示漲/跌/不比價',
#   '當日統計資訊含一般、零股、盤後定價、鉅額交易，不含拍賣、標購。',
#   'ETF證券代號第六碼為K、M、S、C者，表示該ETF以外幣交易。']}

# %%
df=pd.json_normalize(res.json(), max_level=2)


df.head()
# Out:
#   stat      date                              title  \
# 0   OK  20200516  109年05月 2330 台積電           各日成交資訊
#
#                                              fields  \
# 0  [日期, 成交股數, 成交金額, 開盤價, 最高價, 最低價, 收盤價, 漲跌價差, 成交筆數]
#
#                                                 data  \
# 0  [[109/05/04, 72,252,861, 21,341,931,218, 294.5...
#
#                                                notes
# 0  [符號說明:+/-/X表示漲/跌/不比價, 當日統計資訊含一般、零股、盤後定價、鉅額交易，不...
