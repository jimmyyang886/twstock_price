# %%
from datetime import datetime
import os

code='2330'
def dlcheck(path):
    filename=os.listdir(path)
    code_cap=[]
    for _file in filename:
        code_cap.append(_file[:-8])
    code_cap=set(code_cap)
    return code_cap
jsonpath='data'
code_cap=dlcheck(jsonpath)
print(code_cap)

year, month =2020, 5
ym=datetime.strptime(str(year)+'-'+str(month), "%Y-%m")
fc='{}_{:%Y-%m}'.format(code, ym)
print(fc)

# %%
from TWstockPrice import Stock
import time
import random
import os
from requests.exceptions import ConnectionError
import json
from codes import codes
from datetime import datetime

def dlcheck(path):
    filename=os.listdir(path)
    code_cap=[]
    for _file in filename:
        code_cap.append(_file[:-8])
    code_cap=set(code_cap)
    return code_cap
            

jsonpath='data'
if not os.path.exists(jsonpath):
    os.mkdir(jsonpath)
    
code_cap=dlcheck(jsonpath)


stockDict={}
stockList=[]

year, month =2020,1
ym=datetime.strptime(str(year)+'-'+str(month), "%Y-%m")

#code='1101'

for code,v in codes.items():
    if v.type=="股票" and v.market=="上市":
        try:
            #print(code)
            fc='{}_{:%Y-%m}'.format(code, ym)
            #print(fc)   
            if fc not in code_cap:
                #print(fc)

                stock= Stock(code)
                stock.fetch(year, month)

                stockDict={}

                print('write to:', fc)
                for _data in stock.data:
                    ymd='{:%Y-%m-%d}'.format(_data.date)
                    filename=code+'_'+ymd+'.json'
                    stockDict['code'] =code           
                    content =dict(_data._asdict())
                    for k, v in content.items():
                        if k is 'date':
                            stockDict[k] = '{:%Y-%m-%d}'.format(_data.date)
                        else:
                            stockDict[k] = v

                    #print('write to:', filename)
                    with open(jsonpath+'/'+filename, 'w') as f:
                        json.dump(stockDict, f)

        except ConnectionError:
            code_cap=dlcheck(jsonpath)
            break
            #time.sleep(120)
            #continue
# Out:
# write to: 1101_2020-01
# write to: 1102_2020-01
# write to: 1103_2020-01
# write to: 1104_2020-01
# write to: 1108_2020-01
# write to: 1109_2020-01
# write to: 1110_2020-01
# write to: 1201_2020-01
# write to: 1203_2020-01
# write to: 1210_2020-01
# write to: 1213_2020-01
# write to: 1215_2020-01
# write to: 1216_2020-01
# write to: 1217_2020-01
# write to: 1218_2020-01
# write to: 1219_2020-01
# write to: 1220_2020-01
# write to: 1225_2020-01
# write to: 1227_2020-01
# write to: 1229_2020-01
# write to: 1231_2020-01
# write to: 1232_2020-01
# write to: 1233_2020-01
# write to: 1234_2020-01
# write to: 1235_2020-01
# write to: 1236_2020-01
# write to: 1256_2020-01
# write to: 1301_2020-01
# write to: 1303_2020-01
# write to: 1304_2020-01
# write to: 1305_2020-01
# write to: 1307_2020-01
# write to: 1308_2020-01
# write to: 1309_2020-01
# write to: 1310_2020-01
# write to: 1312_2020-01
